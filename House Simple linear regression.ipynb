# %% [markdown]
# # House Prices
# kaggle problem

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # read the dataset

# %%
train = pd.read_csv("C:\\Users\\HP\\Documents\\abc\\house prediction\\train.csv")
test = pd.read_csv("C:\\Users\\HP\\Documents\\abc\\house prediction\\test.csv")

# %%
train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
train.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
test.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# # filling the null values

# %%
train['LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean())
test['LotFrontage']=test['LotFrontage'].fillna(test['LotFrontage'].mean())

# %%
train['Exterior2nd']=train['Exterior2nd'].fillna(train['Exterior2nd'].mode()[0])
test['Exterior2nd']=test['Exterior2nd'].fillna(test['Exterior2nd'].mode()[0])

# %%
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
test['BsmtExposure']=test['BsmtExposure'].fillna(test['BsmtExposure'].mode()[0])

# %%
train['BsmtFinType2']=train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])
test['BsmtFinType2']=test['BsmtFinType2'].fillna(test['BsmtFinType2'].mode()[0])

# %%
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
test['BsmtQual']=test['BsmtQual'].fillna(test['BsmtQual'].mode()[0])

# %%
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
test['BsmtExposure']=test['BsmtExposure'].fillna(test['BsmtExposure'].mode()[0])

# %%
train['BsmtFinSF2']=train['BsmtFinSF2'].fillna(train['BsmtFinSF2'].mode()[0])
test['BsmtFinSF2']=test['BsmtFinSF2'].fillna(test['BsmtFinSF2'].mode()[0])
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])

# %%
train['GarageType']=train['GarageType'].fillna(train['GarageType'].mode()[0])
test['GarageType']=test['GarageType'].fillna(test['GarageType'].mode()[0])

# %%
train['FireplaceQu']=train['FireplaceQu'].fillna(train['FireplaceQu'].mode()[0])
test['FireplaceQu']=test['FireplaceQu'].fillna(test['FireplaceQu'].mode()[0])

# %%
train['Fireplaces']=train['Fireplaces'].fillna(train['Fireplaces'].mode()[0])
test['Fireplaces']=test['Fireplaces'].fillna(test['Fireplaces'].mode()[0])

# %%
train['GarageFinish']=train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])
train['GarageQual']=train['GarageQual'].fillna(train['GarageQual'].mode()[0])
train['GarageCond']=train['GarageCond'].fillna(train['GarageCond'].mode()[0])
test['GarageFinish']=test['GarageFinish'].fillna(test['GarageFinish'].mode()[0])
test['GarageQual']=test['GarageQual'].fillna(test['GarageQual'].mode()[0])
test['GarageCond']=test['GarageCond'].fillna(test['GarageCond'].mode()[0])

# %%
train['MasVnrType']=train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])
train['MasVnrArea']=train['MasVnrArea'].fillna(train['MasVnrArea'].mode()[0])
train['BsmtFinType1']=train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])
train['BsmtFinType1']=train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])

test['MasVnrType']=test['MasVnrType'].fillna(test['MasVnrType'].mode()[0])
test['MasVnrArea']=test['MasVnrArea'].fillna(test['MasVnrArea'].mode()[0])
test['BsmtFinType1']=test['BsmtFinType1'].fillna(test['BsmtFinType1'].mode()[0])
test['BsmtFinType1']=test['BsmtFinType1'].fillna(test['BsmtFinType1'].mode()[0])

# %%
train['Utilities']=train['Utilities'].fillna(train['Utilities'].mode()[0])
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtFullBath']=train['BsmtFullBath'].fillna(train['BsmtFullBath'].mode()[0])
train['KitchenQual']=train['KitchenQual'].fillna(train['KitchenQual'].mode()[0])

test['Utilities']=test['Utilities'].fillna(test['Utilities'].mode()[0])
test['BsmtCond']=test['BsmtCond'].fillna(test['BsmtCond'].mode()[0])
test['BsmtFullBath']=test['BsmtFullBath'].fillna(test['BsmtFullBath'].mode()[0])
test['KitchenQual']=test['KitchenQual'].fillna(test['KitchenQual'].mode()[0])

# %%
train['MSZoning']=train['MSZoning'].fillna(train['MSZoning'].mode()[0])
train['Exterior1st']=train['Exterior1st'].fillna(train['Exterior1st'].mode()[0])
train['BsmtFinSF1']=train['BsmtFinSF1'].fillna(train['BsmtFinSF1'].mode()[0])
train['TotalBsmtSF']=train['TotalBsmtSF'].fillna(train['TotalBsmtSF'].mode()[0])
train['BsmtHalfBath']=train['BsmtHalfBath'].fillna(train['BsmtHalfBath'].mode()[0])
train['GarageArea']=train['GarageArea'].fillna(train['GarageArea'].mode()[0])
train['GarageCars']=train['GarageCars'].fillna(train['GarageCars'].mode()[0])
train['SaleType']=train['SaleType'].fillna(train['SaleType'].mode()[0])
train['BsmtUnfSF']=train['BsmtUnfSF'].fillna(train['BsmtUnfSF'].mode()[0])
train['Functional']=train['Functional'].fillna(train['Functional'].mode()[0])
train['BsmtUnfSF']=train['BsmtUnfSF'].fillna(train['BsmtUnfSF'].mode()[0])



test['MSZoning']=test['MSZoning'].fillna(test['MSZoning'].mode()[0])
test['Exterior1st']=test['Exterior1st'].fillna(test['Exterior1st'].mode()[0])
test['BsmtFinSF1']=test['BsmtFinSF1'].fillna(test['BsmtFinSF1'].mode()[0])
test['TotalBsmtSF']=test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].mode()[0])
test['BsmtHalfBath']=test['BsmtHalfBath'].fillna(test['BsmtHalfBath'].mode()[0])
test['GarageArea']=test['GarageArea'].fillna(test['GarageArea'].mode()[0])
test['GarageCars']=test['GarageCars'].fillna(test['GarageCars'].mode()[0])
test['SaleType']=test['SaleType'].fillna(test['SaleType'].mode()[0])
test['BsmtUnfSF']=test['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mode()[0])
test['Functional']=test['Functional'].fillna(test['Functional'].mode()[0])
test['BsmtUnfSF']=test['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mode()[0])

# %%
train.drop(['PoolQC','Fence','MiscFeature','GarageYrBlt','Alley'],axis=1,inplace=True)


test.drop(['PoolQC','Fence','MiscFeature','GarageYrBlt','Alley'],axis=1,inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   object
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   LotShape       1459 non-null   object
#  7   LandContour    1459 non-null   object
#  8   Utilities      1459 non-null   object
#  9   LotConfig      1459 non-null   object
#  10  LandSlope      1459 non-null   object
#  11  Neighborhood   1459 non-null   object
#  12  Condition1     1459 non-null   object
#  13  Condition2     1459 non-null   object
#  14  BldgType       1459 non-null   object
#  15  HouseStyle     1459 non-null   object
#  16  OverallQual    1459 non-null   int64
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 76)
# (1459, 75)

# %%
lst=['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %% [markdown]
# # convert the categorical to numerical

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
for i in lst:
    train[i]= label.fit_transform(train[i])
    test[i]= label.fit_transform(test[i])

# %%
train.shape
# Out:
# (1460, 76)

# %%
test.shape
# Out:
# (1459, 75)

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 76)
# (1459, 75)

# %% [markdown]
# # split the data

# %%
X_train=train.drop(['SalePrice'],axis=1)
y_train=train['SalePrice']

# %% [markdown]
# # linear Regression

# %%
# creare model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #test overfit or not

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train ,test_size=0.3, random_state=10)

# %%
lr  = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(test)

# %%
lr.score(X_test,y_test)
# Out:
# 0.8323196251280474

# %%
y_pred
# Out:
# array([ 99525.43418792, 156488.27993348, 160543.85247113, ...,
#        130636.7489254 , 110070.88333314, 244856.22510829])

# %%
train["Id"]
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64

# %%
dataframe= pd.DataFrame({'ID':test["Id"],"SalePrice":y_pred})

# %%
dataframe
# Out:
#         ID      SalePrice
# 0     1461   99525.434188
# 1     1462  156488.279933
# 2     1463  160543.852471
# 3     1464  184756.993210
# 4     1465  192423.546026
# ...    ...            ...
# 1454  2915   63792.621099
# 1455  2916   57474.955046
# 1456  2917  130636.748925
# 1457  2918  110070.883333
# 1458  2919  244856.225108
#
# [1459 rows x 2 columns]

# %%
#dataframe.to_csv(r"submission1.csv",index=False)

# %% [markdown]
# # Decision Tree regression

# %%
from sklearn.model_selection import train_test_split #test overfit or not
from sklearn.tree import  DecisionTreeRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train ,test_size=0.3, random_state=10)

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Find the accuracy
model.score(X_test,y_test)
# Out:
# 0.7681142533023468

# %% [markdown]
# # XGBRegression

# %%
import xgboost
model=xgboost.XGBRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
model.score(X_test,y_test)
# Out:
# 0.7761427701198215

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
model = SVR(kernel='rbf')
model.fit(X_train,y_train)
# Out:
# SVR()

# %%
model.score(X_test,y_test)
# Out:
# -0.0294477048994084

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=21)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=21)

# %%
model.score(X_test,y_test)
# Out:
# 0.7762439655327406

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 1000, random_state=51)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=51)

# %%
model.score(X_test,y_test)
# Out:
# 0.8847057054638163

# %%
y_pred = model.predict(test)

# %%
y_pred
# Out:
# array([122493.388, 153717.369, 179205.568, ..., 151518.985, 125017.374,
#        236266.503])

# %%
dataframe= pd.DataFrame({'ID':test["Id"],"SalePrice":y_pred})

# %%
#dataframe.to_csv(r"submission2.csv",index=False)

# %% [markdown]
# # BaggingRegressor, GradientBoostingRegressor

# %%
from sklearn.ensemble import BaggingRegressor, GradientBoostingRegressor
model1 = BaggingRegressor(n_estimators=1000, random_state=51)
model2 = GradientBoostingRegressor(n_estimators=1000, learning_rate=0.1, loss='ls', random_state=51)

# %%
model1.fit(X_train,y_train)
# Out:
# BaggingRegressor(n_estimators=1000, random_state=51)

# %%
model1.score(X_test,y_test)
# Out:
# 0.8843957874517318

# %%
model2.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=1000, random_state=51)

# %%
model2.score(X_test,y_test)
# Out:
# 0.9067530066136364

# %%
y_pred = model2.predict(test)

# %%
dataframe= pd.DataFrame({'ID':test["Id"],"SalePrice":y_pred})

# %%
#dataframe.to_csv(r"submission3.csv",index=False)

# %% [markdown]
# # xgboost

# %%
import xgboost
model=xgboost.XGBRegressor()
model = xgboost.XGBRegressor(bbooster='gbtree', random_state=51)

# %%
model.fit(X_train,y_train)
# Out:
# [23:43:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "bbooster" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, bbooster='gbtree', booster='gbtree',
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=51,
# ...

# %%
model.score(X_test,y_test)
# Out:
# 0.8943785387058815

# %% [markdown]
# ## GradientBoostingRegressor
# * it gives the best accua
